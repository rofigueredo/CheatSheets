# %% [markdown]
# Secciones del Curso. Del 1 al 5
#
# ### EDA Proveedores, Concepto

# %%
import pandas as pd
pd.show_versions()
# Out:
# d:\Anaconda\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit              : a60ad39b4a9febdea9a59d602dad44b1538b0ea5
# python              : 3.10.12.final.0
# python-bits         : 64
# OS                  : Windows
# OS-release          : 10
# Version             : 10.0.26100
# machine             : AMD64
# processor           : AMD64 Family 23 Model 24 Stepping 1, AuthenticAMD
# byteorder           : little
# LC_ALL              : None
# LANG                : None
# LOCALE              : es_ES.cp1252
#
# pandas              : 2.1.2
# numpy               : 1.25.2
# pytz                : 2022.7
# dateutil            : 2.8.2
# setuptools          : 65.6.3
# pip                 : 24.0
# Cython              : None
# pytest              : None
# hypothesis          : None
# sphinx              : None
# blosc               : None
# ...

# %%
# Usando raw string (recomendado en Windows)
tabla = pd.read_csv(r"C:\Users\rfigu\Documents\Learn\CARRERA_DATOS\Pandas_de1.5horas\BasesEjemplo\TablaEjemplo.csv" ## VentasPorProveedor.csv"
                    , sep=",")
                    #,skiprows=5)
tabla.head()
# Out:
#   Nombre  Edad       País Automovil
# 0   Juan    35     México        No
# 1  Pedro    41     España        Si
# 2  María    28       Perú        Si
# 3  Laura    66  Argentina        No

# %%
##leer una serie especifica, siempre y cuando no tenga espacio em el nombre
tabla.Edad
# Out:
# 0    35
# 1    41
# 2    28
# 3    66
# Name: Edad, dtype: int64

# %%
## leer varias serie a la vez se utiliza 2 corchetes
tabla[['Edad','País']]
# Out:
#    Edad       País
# 0    35     México
# 1    41     España
# 2    28       Perú
# 3    66  Argentina

# %%
# al invocar una serie, te detalla el tipo de objeto
tabla['Nombre']
# Out:
# 0     Juan
# 1    Pedro
# 2    María
# 3    Laura
# Name: Nombre, dtype: object

# %%
# Type me indica que tipo 
#  cuando tomo 1 columnas me devuel SERIE
type(tabla.Edad)
# Out:
# pandas.core.series.Series

# %%
# Si tomo 2 ya se convierte en DataFrame
type(tabla[['Edad','País']])
# Out:
# pandas.core.frame.DataFrame

# %%
VentasPorProveedor = pd.read_csv(r"C:\Users\rfigu\Documents\Learn\CARRERA_DATOS\Pandas_de1.5horas\BasesEjemplo\VentasPorProveedor.csv" ## TablaEjemplo.csv"
                    , sep=";"
                    ,skiprows=5)
VentasPorProveedor.head() ## Sirve para visualizar las 1ras 5 lineas de tu DataFrame
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 0  1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2  1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
## el resumen de tu datadrame, tipo datos, nro de filas y nulos
VentasPorProveedor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      460 non-null    object
#  1   Vendedor   460 non-null    object
#  2   Región     460 non-null    object
#  3   Artículo   460 non-null    object
#  4   Categoría  460 non-null    object
#  5   Unidades   460 non-null    int64
#  6   Ganancia   460 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 25.3+ KB

# %% [markdown]
# VALUE_COUNT. Devuelve un objeto de tipo serie y los ordena de forma descendente

# %%
VentasPorProveedor.Vendedor.value_counts()
# Out:
# Vendedor
# Sarah Bond          86
# Steve Ashton        84
# Desmond Delaney     76
# Trevor Snodgrass    75
# Dustin Gee          70
# Boris Stanford      69
# Name: count, dtype: int64

# %%
VentasPorProveedor.sort_values(by=['Vendedor','Ganancia'])
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 93    6/1/2016    Boris Stanford  Norte   Chocolate  Comestibles         2
# 450  31/1/2016    Boris Stanford   Este   Chocolate  Comestibles         3
# 259  18/1/2016    Boris Stanford    Sur   Pepinillo  Comestibles         5
# 25    2/1/2016    Boris Stanford   Este         Pan  Comestibles         4
# 64    5/1/2016    Boris Stanford    Sur         Pan  Comestibles         4
# ..         ...               ...    ...         ...          ...       ...
# 231  15/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         4
# 314  21/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 328  22/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 69    5/1/2016  Trevor Snodgrass  Norte  Calcetines   Vestimenta         4
# 238  16/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         2
#
#     Ganancia
# 93      0,96
# 450     1,44
# 259     1,50
# ...

# %% [markdown]
# Indexacion Booleana

# %%
## De esta forma solo cumple si es o no es , True or False, info que no esta tan util
VentasPorProveedor.Artículo == 'Gorras'
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 455    False
# 456    False
# 457    False
# 458    False
# 459    False
# Name: Artículo, Length: 460, dtype: bool

# %%
## de esta forma es bastante mas util, EJ filtro por 1 Dim

VentasPorProveedor[VentasPorProveedor.Artículo == 'Gorras']
# Out:
#          Fecha          Vendedor Región Artículo   Categoría  Unidades  \
# 2     1/1/2016        Sarah Bond    Sur   Gorras  Vestimenta         3
# 7     1/1/2016      Steve Ashton  Oeste   Gorras  Vestimenta         2
# 38    4/1/2016      Steve Ashton  Oeste   Gorras  Vestimenta        13
# 57    4/1/2016        Dustin Gee   Este   Gorras  Vestimenta         2
# 85    6/1/2016        Sarah Bond  Norte   Gorras  Vestimenta         9
# 156  10/1/2016  Trevor Snodgrass  Norte   Gorras  Vestimenta         7
# 159  11/1/2016      Steve Ashton  Norte   Gorras  Vestimenta         2
# 170  11/1/2016        Sarah Bond   Este   Gorras  Vestimenta         9
# 186  12/1/2016        Sarah Bond   Este   Gorras  Vestimenta        11
# 187  12/1/2016        Dustin Gee    Sur   Gorras  Vestimenta        13
# 201  14/1/2016   Desmond Delaney  Norte   Gorras  Vestimenta         5
# 231  15/1/2016  Trevor Snodgrass   Este   Gorras  Vestimenta         4
# ...

# %%
## de esta forma es bastante mas util, EJ filtro por 1 Dim
## Obs: los indices no se reinician
VentasPorProveedor[(VentasPorProveedor.Artículo == 'Gorras') & (VentasPorProveedor.Región =='Norte')]
# Out:
#          Fecha          Vendedor Región Artículo   Categoría  Unidades  \
# 85    6/1/2016        Sarah Bond  Norte   Gorras  Vestimenta         9
# 156  10/1/2016  Trevor Snodgrass  Norte   Gorras  Vestimenta         7
# 159  11/1/2016      Steve Ashton  Norte   Gorras  Vestimenta         2
# 201  14/1/2016   Desmond Delaney  Norte   Gorras  Vestimenta         5
# 360  25/1/2016      Steve Ashton  Norte   Gorras  Vestimenta         7
# 368  26/1/2016    Boris Stanford  Norte   Gorras  Vestimenta         7
# 394  27/1/2016      Steve Ashton  Norte   Gorras  Vestimenta        14
# 396  27/1/2016  Trevor Snodgrass  Norte   Gorras  Vestimenta         3
#
#     Ganancia
# 85     18,90
# 156    14,70
# 159     4,20
# 201    10,50
# 360    14,70
# 368    14,70
# 394    29,40
# 396     6,30

# %%
VentasPorProveedor[VentasPorProveedor.Vendedor.str.contains('Trevor')]
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 1     1/1/2016  Trevor Snodgrass  Oeste   Chocolate  Comestibles         8
# 5     1/1/2016  Trevor Snodgrass   Este     Cerveza  Comestibles        15
# 8     1/1/2016  Trevor Snodgrass   Este         Pan  Comestibles        12
# 10    1/1/2016  Trevor Snodgrass    Sur         Pan  Comestibles         6
# 12    1/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         6
# ..         ...               ...    ...         ...          ...       ...
# 437  30/1/2016  Trevor Snodgrass   Este  Calcetines   Vestimenta        10
# 440  30/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         6
# 442  31/1/2016  Trevor Snodgrass   Este   Sandalias   Vestimenta         6
# 446  31/1/2016  Trevor Snodgrass  Oeste    Sudadera   Vestimenta         2
# 459  31/1/2016  Trevor Snodgrass    Sur   Pepinillo  Comestibles         7
#
#     Ganancia
# 1       3,84
# 5       6,00
# 8       4,80
# ...
