# %% [markdown]
# ### Adventure Works data files

# %%
# Librerias
import pandas as pd
import os
import sqlalchemy as sql
import time

# %%
server = 'ASUSTUF\SQL22'; database = 'AdventureWorks2019'
try:
    engine = sql.create_engine(f"mssql+pyodbc://{server}/{database}?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server")
    print('Conexión exitosa')
except sql.Error as e:
    print(f'Error al conectar a la base de datos: {str(e)}')

current_time = time.strftime("%H:%M:%S", time.localtime())
print(current_time)
# Out:
# Conexión exitosa
# 21:50:54

# %%
SalesCustomer = pd.read_sql('SELECT * FROM sales.vIndividualCustomer', engine)
print( f"Filas, Col: {SalesCustomer.shape}")
SalesCustomer.head()
# Out:
# Filas, Col: (18508, 18)
#    BusinessEntityID Title  FirstName MiddleName  LastName Suffix  \
# 0              1699   Mr.      David         R.  Robinett   None
# 1              1700   Ms.    Rebecca         A.  Robinson   None
# 2              1701   Ms.    Dorothy         B.  Robinson   None
# 3              1702   Ms.  Carol Ann         F.    Rockne   None
# 4              1703   Mr.      Scott         M.   Rodgers   None
#
#     PhoneNumber PhoneNumberType                   EmailAddress  \
# 0  238-555-0100            Home    david22@adventure-works.com
# 1  648-555-0100            Cell   rebecca3@adventure-works.com
# 2  423-555-0100            Cell   dorothy3@adventure-works.com
# 3  439-555-0100            Cell  carolann0@adventure-works.com
# 4  989-555-0100            Cell    scott10@adventure-works.com
#
#    EmailPromotion AddressType          AddressLine1 AddressLine2  \
# 0               1        Home      Pappelallee 6667         None
# ...

# %%
SalesCustomer.to_excel(r'SalesCustomer.xlsx', index=False)

# %%
# SalesInvoices = pd.read_sql(f'SELECT H.OrderDate, H.SalesOrderNumber, H.CustomerID, H.TotalDue, d.OrderQty, D.ProductID, d.LineTotal FROM Sales.SalesOrderHeader H JOIN SALES.SalesOrderDetail D ON H.SalesOrderID=D.SalesOrderID JOIN Production.vProductAndDescription P ON P.ProductID=P.ProductID', engine)
SalesInvoices = pd.read_sql('SELECT * FROM Sales.SalesOrderHeader', engine)
print( f"Filas, Col: {SalesInvoices.shape}")
SalesInvoices.head(3)
# Out:
# Filas, Col: (31465, 26)
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43659               8 2011-05-31 2011-06-12 2011-06-07       5
# 1         43660               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43661               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  ...  \
# 0            False          SO43659         PO522145787  10-4020-000676  ...
# 1            False          SO43660       PO18850127500  10-4020-000117  ...
# 2            False          SO43661       PO18473189620  10-4020-000442  ...
#
#    CreditCardID  CreditCardApprovalCode  CurrencyRateID    SubTotal  \
# 0       16281.0           105041Vi84182             NaN  20565.6206
# 1        5618.0           115213Vi29411             NaN   1294.2529
# 2        1346.0             85274Vi6854             4.0  32726.4786
#
#       TaxAmt   Freight    TotalDue Comment  \
# ...

# %%
SalesInvoices.to_excel(r'Invoices.xlsx', index=False)
